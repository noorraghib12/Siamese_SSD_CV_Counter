# %%
import os
import dlib
import cv2
import time
import numpy as np
from PIL import Image
from scipy.spatial import distance as dist
from collections import OrderedDict
import tensorflow as tf


gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)


label_map= ["ep_black","ep_green","ep_orange"]
label_map.sort()
detect_fn=tf.saved_model.load(".\\saved_model")

# %%
detect_fn
# Out:
# <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject at 0x179360ec488>

# %%
import math
from tensorflow.keras.applications import resnet50
from tensorflow.keras.layers import Dense, Conv2D, Flatten 
from tensorflow.keras import Model
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
 
# load class model
class_model = load_model('.\\imageacc_model.h5')

#Backbone_SNN
# base_resnet=tf.keras.applications.ResNet50(include_top=False,weights="imagenet",input_shape=(150,150,3),classes=len(label_map))
# # for i in base_resnet.layers[:(math.ceil(len(base_resnet.layers)/2))]:
# #     i.trainable=False
# conv1=Conv2D(48,(1,1),padding="valid",activation="relu")
# dr1=layers.Dropout(0.3)
# avgpool1 = tf.keras.layers.AveragePooling2D(pool_size=(2, 2))
# conv2=Conv2D(78,(1,1),padding="same",activation="relu")
# dr2=layers.Dropout(0.2)
# flatten_layer = Flatten()
# dense1 = Dense(108,activation='sigmoid')

# embedding_model=tf.keras.Sequential([base_resnet,conv1,avgpool1,conv2,flatten_layer,dense1])
# embedding_model.load_weights(".\\checkpoint_94_0.00.hdf5")

# %%
class_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_5 (Sequential)   (None, 108)               23723690
#
#  dense_9 (Dense)             (None, 3)                 327
#
# =================================================================
# Total params: 23,724,017
# Trainable params: 327
# Non-trainable params: 23,723,690
# _________________________________________________________________

# %%
def detect_boxes(frame, detect_fn,thresh,H,W):
        image_np = np.array(frame)
        input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.uint8)
        detections = detect_fn(input_tensor)
        # detection_classes should be ints.
        score_mask=(detections['detection_scores']>0.5).numpy().reshape(-1)
        rects_masked=detections['detection_boxes'].numpy().reshape(100,4)[score_mask]
        rects=(rects_masked*np.array([H,W,H,W])).astype(int)
        func=lambda x: (x[1]+x[3])/2
        rect_mask=np.array(list(map(func,rects)))>600*0.30
        print(rects)
        print(rect_mask)
        valid_rects=rects[rect_mask]
        print("Valid_rects\n {}".format(valid_rects))
        return valid_rects
    
def visualize_boxes(image,tracks):    
    for id_,track in tracks.items():
        (startY,startX,endY,endX) = track.box
        name="unknown" if track.name==None else track.name
        # draw the bounding box of the face along with the associated probability
        cv2.rectangle(image, (startX, startY), (endX, endY), (0, 0, 255), 2)
        cv2.putText(image, name, (startX, startY),cv2.FONT_HERSHEY_SIMPLEX, 0.65, (255, 255, 255), 2)
        #cv2.putText(image, name, (startX, startY),cv2.FONT_HERSHEY_SIMPLEX, 0.45, (255, 255,255), 2) 
    return image

# %%
# def get_name(model,svm,face_pixels,label_map):
#     img=cv2.resize(face_pixels,(160,160))
#     img = np.around(np.array(img) / 255.0, decimals=12)
#     x_train = np.expand_dims(img, axis=0)
#     embedding = model.predict(x_train)
#     embedding= embedding / np.linalg.norm(embedding, ord=2)
#     name=svm.predict(embedding.reshape(1,-1))
#     return label_map[name]



class Track():
    def __init__(self,tracker,box):
        self.tracker=tracker
        self.box=box
        self.recognized_face=False
        self.encodings=None 
        self.name=None
        self.prob_face={}
        self.centroid=self.get_centroid()
        self.rec_count=0
        #self.spoof_confirm=[]


    def update_track(self,frame):
        self.tracker.update(frame)
        pos=self.tracker.get_position()
        startX = int(pos.left())
        startY = int(pos.top())
        endX = int(pos.right())
        endY = int(pos.bottom())
        tracked_box=np.array([startY,startX,endY,endX])
        print("tracked_box")
        #print(("tracked_box",tracked_box))
        prev_box=np.array(self.box)
        #self.box=tracked_box.astype('int')
        return tracked_box
        #print(("prev_box",prev_box))
        #self.box=self.box if get_overlap(tracked_box,prev_box)>0.95 else tracked_box.astype('int')
        
    def box_recognize(self,image,class_model,label_map,tracker):
        global W,H
        if (self.name==None and 0.46*W<self.get_centroid()[1]<0.50*W):
            starty,startx,endy,endx=self.box
            box_roi = image[starty:endy,startx:endx]  
            img=cv2.cvtColor(box_roi,cv2.COLOR_BGR2RGB)
            im = Image.fromarray(img, 'RGB')
            #Resizing into dimensions you used
            im = im.resize((150,150))
            img_array = (np.array(im).astype(np.float32)/255)
            #Expand dimensions to match the 4 D Tensor shape.
            img_array = np.expand_dims(img_array, axis = 0)
            idx_=class_model.predict(img_array)
            name=label_map[np.argmax(idx_)]
            self.name=name
            tracker.count[name]=tracker.count.get(name,0)+1
            print(tracker.count)
    def get_box(self):
        pos=self.tracker.get_position()
        return [int(pos.left()),int(pos.top()),int(pos.right()),int(pos.bottom())]


    def get_centroid(self):
        box=self.box
        return (int((box[0]+box[2])/2),int((box[1]+box[3])/2))


class Tracker():
    
    global frame
    
    def __init__(self, maxDisappeared=5,maxDistance=150,thresh=None):
        # initialize the next unique object ID along with two ordered
        # dictionaries used to keep track of mapping a given object
        # ID to its centroid and number of consecutive frames it has
        # been marked as "disappeared", respectively
        self.nextObjectID = 0
        self.objects = OrderedDict()
        self.disappeared = OrderedDict()
        self.count={}
        self.thresh=thresh
        # store the number of maximum consecutive frames a given
        # object is allowed to be marked as "disappeared" until we
        # need to deregister the object from tracking
        self.maxDisappeared = maxDisappeared
        self.maxDistance=maxDistance

    def register(self, rect,frame):
    
        # when registering an object we use the next available object
        # ID to store the centroid
        t = dlib.correlation_tracker()
        (startY, startX, endY, endX)=rect
        drect = dlib.rectangle(startX, startY, endX, endY)
        t.start_track(frame, drect)
        name='obj_'+str(self.nextObjectID)
        self.objects[name] = Track(t,rect)
        self.disappeared[name] = 0
        self.nextObjectID+=1

    def deregister(self, objectID):
        # to deregister an object ID we delete the object ID from
        # both of our respective dictionaries
        trk=self.objects[objectID]
        startY,startX,endY,endX=trk.box
        print("vanishing_arr: {}".format(trk.box))
#         if int(startX/2+endX/2) <self.thresh:     
#             name=trk.name
#             self.count[name]=self.count.get(name,0)+1
        del self.objects[objectID]
        del self.disappeared[objectID]
        
    def deregister(self, objectID):
        # to deregister an object ID we delete the object ID from
        # both of our respective dictionaries
#         trk=self.objects[objectID]
#         startY,startX,endY,endX=trk.box
#         if int(startX/2+endX/2) <self.thresh:     
#             name=trk.name
#             self.count[name]=self.count.get(name,0)+1
            
        del self.objects[objectID]
        del self.disappeared[objectID]
        
    def track_update(self,frame):
        height,width,channel = frame.shape
        for objectID in list(self.disappeared.keys()):
            trk=self.objects[objectID]
            startY,startX,endY,endX=trk.box
            if int(startX/2+endX/2)<(0.35*width):
                self.disappeared[objectID]+=4.7
            if self.disappeared[objectID]>self.maxDisappeared:
                self.deregister(objectID)
        t_rects=[]
        for name in self.objects.keys():
            t_rect=self.objects[name].update_track(frame)
            t_rects.append(t_rect)
        return np.array(t_rects)


    def update(self,frame, coords,thresh):
        
        for objectID in list(self.disappeared.keys()):
            trk=self.objects[objectID]
            if trk.centroid[0]<thresh:
                self.disappeared[objectID]+=1.7
        
        
        
        if len(coords) == 0:
            # loop over any existing tracked objects and mark them
            # as disappeared
            for objectID in list(self.disappeared.keys()):
                self.disappeared[objectID] += 1

                # if we have reached a maximum number of consecutive
                # frames where a given object has been marked as
                # missing, deregister it
                if self.disappeared[objectID] > self.maxDisappeared:
                    self.deregister(objectID)

            # return early as there are no centroids or tracking info
            # to update
            return self.objects
        inputCentroids = np.zeros((len(coords), 2), dtype="int")

        # loop over the bounding box rectangles
        for (i, (startY, startX, endY, endX)) in enumerate(coords):
            # use the bounding box coordinates to derive the centroid
            cX = int((startX + endX) / 2.0)
            cY = int((startY + endY) / 2.0)
            inputCentroids[i] = (cX, cY)

        # initialize an array of input centroids for the current frame
        
        # if we are currently not tracking any objects take the input
        # centroids and register each of them

        if len(self.objects) == 0:
            for i in range(0, len(coords)):
                self.register(coords[i],frame)
            
            
        # otherwise, are are currently tracking objects so we need to
        # try to match the input centroids to existing object
        # centroids
        else:
            # grab the set of object IDs and corresponding centroids
            object_copy=self.objects.copy()
            tracks_copy=list(object_copy.values())
            #print('tracks:'+str(tracks_copy))
            objectIDs = list(object_copy.keys())
            #print('objectIDs:' + str(objectIDs))
            objectCentroids = [i.centroid for i in tracks_copy]

            # compute the distance between each pair of object
            # centroids and input centroids, respectively -- our
            # goal will be to match an input centroid to an existing
            # object centroid
            D = dist.cdist(np.array(objectCentroids), inputCentroids)

            # in order to perform this matching we must (1) find the
            # smallest value in each row and then (2) sort the row
            # indexes based on their minimum values so that the row
            # with the smallest value as at the *front* of the index
            # list
            rows = D.min(axis=1).argsort()
            # next, we perform a similar process on the columns by
            # finding the smallest value in each column and then
            # sorting using the previously computed row index list
            cols = D.argmin(axis=1)[rows]
            
            # in order to determine if we need to update, register,
            # or deregister an object we need to keep track of which
            # of the rows and column indexes we have already examined
            usedRows = set()
            usedCols = set()

            # loop over the combination of the (row, column) index
            # tuples
            for (row, col) in zip(rows, cols):
                # if we have already examined either the row or
                # column value before, ignore it
                # val
                if row in usedRows or col in usedCols:
                    continue
                # if the distance between centroids is greater than
                # the maximum distance, do not associate the two
                # centroids to the same object
                if D[row, col] > self.maxDistance:
                    continue

                # otherwise, grab the object ID for the current row,
                # set its new centroid, and reset the disappeared
                # counter
                objectID = objectIDs[row]
                prev_name=self.objects[objectID].name
                prev_recog_state=self.objects[objectID].recognized_face
                t = dlib.correlation_tracker()
                (y1,x1,y2,x2)=coords[col]
                #name=names[col]
                rect=coords[col]
                drect = dlib.rectangle(int(x1),int(y1),int(x2),int(y2))
                t.start_track(frame, drect)
                n_track=Track(t,rect)
                self.objects[objectID] = n_track
                self.objects[objectID].name=prev_name
                self.objects[objectID].recognized_face=prev_recog_state
                #self.objects[objectID].box = coords[col]
                self.disappeared[objectID] = 0

                # indicate that we have examined each of the row and
                # column indexes, respectively
                usedRows.add(row)
                usedCols.add(col)

            # compute both the row and column index we have NOT yet
            # examined
            unusedRows = set(range(0, D.shape[0])).difference(usedRows)
            unusedCols = set(range(0, D.shape[1])).difference(usedCols)

            # in the event that the number of object centroids is
            # equal or greater than the number of input centroids
            # we need to check and see if some of these objects have
            # potentially disappeared
            if D.shape[0] >= D.shape[1]:
                # loop over the unused row indexes
                for row in unusedRows:
                    # grab the object ID for the corresponding row
                    # index and increment the disappeared counter
                    objectID = objectIDs[row]
                    self.disappeared[objectID] += 1

                    # check to see if the number of consecutive
                    # frames the object has been marked "disappeared"
                    # for warrants deregistering the object
                    if self.disappeared[objectID] > self.maxDisappeared:
                        self.deregister(objectID)

            # otherwise, if the number of input centroids is greater
            # than the number of existing object centroids we need to
            # register each new input centroid as a trackable object
            else:
                for col in unusedCols:
                    self.register(coords[col],frame)

        # return the set of trackable objects
        return self.objects

# %%
import imutils
import time
from PIL import Image
cap=cv2.VideoCapture(".\\ch01_20210829090713_1.mp4")
#if vid_path:
    #cap=cv2.VideoCapture(r'G:\Wondershare UniConverter\Converted\ch01_20210707001338.mp4')
#else:

fps = cap.get(cv2.CAP_PROP_FPS)
W = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
H = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#out = cv2.VideoWriter('full_output.avi',cv2.VideoWriter_fourcc('M','J','P','G'), fps, (W,H))
fc=0
thresh=int(600*0.30)
tic=time.time()
name_thresh=600*0.50
tracker=Tracker(maxDisappeared=2,maxDistance=150,thresh=thresh)
func=lambda x: (x[1]+x[3])/2
FPS=[]
while True:
    ret, frame = cap.read()
    if not ret:
        break
    start=time.time()
    img=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    im = Image.fromarray(img, 'RGB')
            #Resizing into dimensions you used
    im = im.resize((337,600))
    img_array = (np.array(im).astype(np.float32))
            #Expand dimensions to match the 4 D Tensor shape.
    
    frame=imutils.resize(frame, width=600)
    H,W=frame.shape[:2]
    print("height: {}, width: {}".format(H,W))
    if (fc==0 or fc%4==0):
        rects=detect_boxes(img_array, detect_fn,thresh,H,W)
#         rect_mask=np.array(list(map(func,rects)))>thresh
#         print(rects)
#         print(rect_mask)
#         valid_rects=rects[rect_mask]
        tracker.objects=tracker.update(frame,rects,thresh)
       
    else:
        t_rects=tracker.track_update(frame)
#         rect_mask=np.array(list(map(func,t_rects)))>thresh
#         print(rects)
#         print(rect_mask)
#         valid_rects=t_rects[rect_mask]  
#         print("tracked_valids: \n {}".format(valid_rects))
        tracker.objects=tracker.update(frame,t_rects,thresh)
            
    #Performing Liveness test for antispoofing and 
    #implementing face recognition per face tracked
    for i in tracker.objects.values():
        i.box_recognize(frame,class_model,label_map,tracker)
    image=visualize_boxes(frame,tracker.objects)
    y_stat=20
    for item,count in tracker.count.items():
        cv2.putText(image,'{}: {}'.format(item,count),(0,y_stat),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
        y_stat+=20
    blk = np.zeros(image.shape, np.uint8)
    cv2.rectangle(blk, (int(0.45*W),0), (int(0.55*W), 337), (0, 255, 0), -1)
    res = cv2.addWeighted(image,1, blk, 0.25, 1)

    # Putting the image back to its position
    res=imutils.resize(res,width=1200)
    cv2.imshow('faces',res)
    fc+=1
    end=time.time()
    print("FPS: {}".format(1/(end-start)))
    FPS.append(int(1/(end-start)))
    print(tracker.objects.keys())
    if cv2.waitKey(10) & 0xff==ord('q'):
        print("STOPPING APPLICATION")
        
        break
print("MEAN FPS THROUGHOUT VIDEO: {}".format(np.array(FPS).sum()/len(FPS)))        
cap.release()
cv2.destroyAllWindows()
# Out:
# height: 337, width: 600
# [[ 94 455 165 542]]
# [ True]
# Valid_rects
#  [[ 94 455 165 542]]
# FPS: 0.25454294979574016
# odict_keys(['obj_0'])
# height: 337, width: 600
# tracked_box
# FPS: 19.305192324509925
# odict_keys([])
# height: 337, width: 600
# FPS: 23.113952232423316
# odict_keys([])
# height: 337, width: 600
# FPS: 22.579763667196037
# odict_keys([])
# height: 337, width: 600
# [[102 453 171 549]]
# [ True]
# Valid_rects
#  [[102 453 171 549]]
# FPS: 12.754420695086832
# odict_keys(['obj_1'])
# height: 337, width: 600
# tracked_box
# FPS: 20.46211563135736
# odict_keys([])
# height: 337, width: 600
# FPS: 22.788071086674236
# odict_keys([])
# height: 337, width: 600
# FPS: 22.43027279096009
# odict_keys([])
# height: 337, width: 600
# [[111 453 184 553]]
# [ True]
# Valid_rects
#  [[111 453 184 553]]
# FPS: 10.783104095431524
# odict_keys(['obj_2'])
# height: 337, width: 600
# tracked_box
# FPS: 19.990963252466518
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31865969121972
# odict_keys([])
# height: 337, width: 600
# FPS: 23.873050565762814
# odict_keys([])
# height: 337, width: 600
# [[117 450 199 556]]
# [ True]
# Valid_rects
#  [[117 450 199 556]]
# FPS: 12.691820511811857
# odict_keys(['obj_3'])
# height: 337, width: 600
# tracked_box
# FPS: 20.0524174463467
# odict_keys([])
# height: 337, width: 600
# FPS: 24.456868301671157
# odict_keys([])
# height: 337, width: 600
# FPS: 22.786833055354844
# odict_keys([])
# height: 337, width: 600
# [[124 449 209 557]]
# [ True]
# Valid_rects
#  [[124 449 209 557]]
# FPS: 12.227649860940243
# odict_keys(['obj_4'])
# height: 337, width: 600
# tracked_box
# FPS: 19.66055424307196
# odict_keys([])
# height: 337, width: 600
# FPS: 21.333658859133795
# odict_keys([])
# height: 337, width: 600
# FPS: 23.87372998571323
# odict_keys([])
# height: 337, width: 600
# [[129 441 218 555]]
# [ True]
# Valid_rects
#  [[129 441 218 555]]
# FPS: 12.692281388726657
# odict_keys(['obj_5'])
# height: 337, width: 600
# tracked_box
# FPS: 20.47390181635353
# odict_keys([])
# height: 337, width: 600
# FPS: 23.87400176452173
# odict_keys([])
# height: 337, width: 600
# FPS: 24.45472937911412
# odict_keys([])
# height: 337, width: 600
# [[140 433 227 552]]
# [ True]
# Valid_rects
#  [[140 433 227 552]]
# FPS: 11.796166664322978
# odict_keys(['obj_6'])
# height: 337, width: 600
# tracked_box
# FPS: 19.66009346539109
# odict_keys(['obj_6'])
# height: 337, width: 600
# tracked_box
# FPS: 21.34560166925367
# odict_keys(['obj_6'])
# height: 337, width: 600
# tracked_box
# FPS: 20.463213769954333
# odict_keys([])
# height: 337, width: 600
# [[151 421 237 546]]
# [ True]
# Valid_rects
#  [[151 421 237 546]]
# FPS: 12.080090320499528
# odict_keys(['obj_7'])
# height: 337, width: 600
# tracked_box
# FPS: 20.06767205083059
# odict_keys(['obj_7'])
# height: 337, width: 600
# tracked_box
# FPS: 20.053376171966512
# odict_keys(['obj_7'])
# height: 337, width: 600
# tracked_box
# FPS: 20.888072151753743
# odict_keys([])
# height: 337, width: 600
# [[159 409 253 537]]
# [ True]
# Valid_rects
#  [[159 409 253 537]]
# FPS: 12.859218017542945
# odict_keys(['obj_8'])
# height: 337, width: 600
# tracked_box
# FPS: 20.889632640051
# odict_keys(['obj_8'])
# height: 337, width: 600
# tracked_box
# FPS: 20.463513282755592
# odict_keys(['obj_8'])
# height: 337, width: 600
# tracked_box
# FPS: 20.88900841675382
# odict_keys([])
# height: 337, width: 600
# [[169 388 266 523]]
# [ True]
# Valid_rects
#  [[169 388 266 523]]
# FPS: 10.90253672256173
# odict_keys(['obj_9'])
# height: 337, width: 600
# tracked_box
# FPS: 20.46331360658057
# odict_keys(['obj_9'])
# height: 337, width: 600
# tracked_box
# FPS: 20.90035429363019
# odict_keys(['obj_9'])
# height: 337, width: 600
# tracked_box
# FPS: 20.463213769954333
# odict_keys([])
# height: 337, width: 600
# [[174 370 278 505]]
# [ True]
# Valid_rects
#  [[174 370 278 505]]
# FPS: 12.691897322306648
# odict_keys(['obj_10'])
# height: 337, width: 600
# tracked_box
# FPS: 20.462714601435312
# odict_keys(['obj_10'])
# height: 337, width: 600
# tracked_box
# FPS: 20.889424561473408
# odict_keys(['obj_10'])
# height: 337, width: 600
# tracked_box
# FPS: 19.66027777387163
# odict_keys([])
# height: 337, width: 600
# [[181 347 288 483]]
# [ True]
# Valid_rects
#  [[181 347 288 483]]
# FPS: 12.69646922071003
# odict_keys(['obj_11'])
# height: 337, width: 600
# tracked_box
# FPS: 20.888280203389492
# odict_keys(['obj_11'])
# height: 337, width: 600
# tracked_box
# FPS: 20.474201642113073
# odict_keys(['obj_11'])
# height: 337, width: 600
# tracked_box
# FPS: 20.8884882591698
# odict_keys([])
# height: 337, width: 600
# [[188 322 299 453]]
# [ True]
# Valid_rects
#  [[188 322 299 453]]
# FPS: 11.940331139401945
# odict_keys(['obj_12'])
# height: 337, width: 600
# tracked_box
# FPS: 20.47570090264251
# odict_keys(['obj_12'])
# height: 337, width: 600
# tracked_box
# FPS: 20.900770890535536
# odict_keys(['obj_12'])
# height: 337, width: 600
# tracked_box
# FPS: 20.888176177053555
# odict_keys([])
# height: 337, width: 600
# [[198 289 301 421]]
# [ True]
# Valid_rects
#  [[198 289 301 421]]
# FPS: 12.697276368248817
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.56839793876503
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 17.5911958126426
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.58032506567319
# odict_keys(['obj_13'])
# height: 337, width: 600
# [[203 255 308 394]]
# [ True]
# Valid_rects
#  [[203 255 308 394]]
# FPS: 12.533704675444206
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.918315246317196
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.579172812764394
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.230476678938242
# odict_keys(['obj_13'])
# height: 337, width: 600
# [[207 214 314 367]]
# [ True]
# Valid_rects
#  [[207 214 314 367]]
# {'ep_green': 1}
# FPS: 0.7376567956675213
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.240466198438757
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 16.994611064740155
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 17.59894598597725
# odict_keys(['obj_13'])
# height: 337, width: 600
# [[211 177 314 341]]
# [ True]
# Valid_rects
#  [[211 177 314 341]]
# FPS: 12.696238625975457
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.230555917764157
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.568069131605043
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.230555917764157
# odict_keys(['obj_13'])
# height: 337, width: 600
# [[211 148 317 318]]
# [ True]
# Valid_rects
#  [[211 148 317 318]]
# FPS: 13.021785227523216
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.577773840634272
# odict_keys(['obj_13'])
# height: 337, width: 600
# tracked_box
# FPS: 18.578514446693628
# odict_keys(['obj_13'])
# height: 337, width: 600
# FPS: 24.474135969237413
# odict_keys([])
# height: 337, width: 600
# [[211 126 318 289]]
# [ True]
# Valid_rects
#  [[211 126 318 289]]
# FPS: 11.39824663430966
# odict_keys(['obj_14'])
# height: 337, width: 600
# FPS: 18.5808189321012
# odict_keys([])
# height: 337, width: 600
# FPS: 24.455870091250983
# odict_keys([])
# height: 337, width: 600
# FPS: 19.294712969394748
# odict_keys([])
# height: 337, width: 600
# [[209 104 316 253]]
# [False]
# Valid_rects
#  []
# FPS: 14.128515030249135
# odict_keys([])
# height: 337, width: 600
# FPS: 22.78955690184466
# odict_keys([])
# height: 337, width: 600
# FPS: 22.281446223478287
# odict_keys([])
# height: 337, width: 600
# FPS: 23.87372998571323
# odict_keys([])
# height: 337, width: 600
# [[206  83 309 224]]
# [False]
# Valid_rects
#  []
# FPS: 12.854764560934646
# odict_keys([])
# height: 337, width: 600
# FPS: 24.45572749641412
# odict_keys([])
# height: 337, width: 600
# FPS: 23.888687014814014
# odict_keys([])
# height: 337, width: 600
# FPS: 23.87359409862939
# odict_keys([])
# height: 337, width: 600
# [[203  68 301 203]]
# [False]
# Valid_rects
#  []
# FPS: 13.73542395305275
# odict_keys([])
# height: 337, width: 600
# FPS: 22.78782346964832
# odict_keys([])
# height: 337, width: 600
# FPS: 22.282156441913344
# odict_keys([])
# height: 337, width: 600
# FPS: 23.318270770325565
# odict_keys([])
# height: 337, width: 600
# [[202  61 288 177]]
# [False]
# Valid_rects
#  []
# FPS: 13.735199054258945
# odict_keys([])
# height: 337, width: 600
# FPS: 24.4555849032401
# odict_keys([])
# height: 337, width: 600
# FPS: 23.87318644665919
# odict_keys([])
# height: 337, width: 600
# FPS: 22.788194897205198
# odict_keys([])
# height: 337, width: 600
# [[200  51 281 159]
#  [ 70 444 122 517]]
# [False  True]
# Valid_rects
#  [[ 70 444 122 517]]
# FPS: 12.852401147255657
# odict_keys(['obj_15'])
# height: 337, width: 600
# tracked_box
# FPS: 19.282205937790202
# odict_keys([])
# height: 337, width: 600
# FPS: 24.45472937911412
# odict_keys([])
# height: 337, width: 600
# FPS: 23.873865874344
# odict_keys([])
# height: 337, width: 600
# [[ 73 453 128 529]
#  [199  40 266 143]]
# [ True False]
# Valid_rects
#  [[ 73 453 128 529]]
# FPS: 11.940297147802422
# odict_keys(['obj_16'])
# height: 337, width: 600
# tracked_box
# FPS: 20.888176177053555
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31853004948018
# odict_keys([])
# height: 337, width: 600
# FPS: 24.45629788573894
# odict_keys([])
# height: 337, width: 600
# [[194  28 258 135]
#  [ 79 460 137 536]
#  [ 49 396  97 463]]
# [False  True  True]
# Valid_rects
#  [[ 79 460 137 536]
#  [ 49 396  97 463]]
# FPS: 11.796133488578773
# odict_keys(['obj_17', 'obj_18'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 18.239355711235483
# odict_keys([])
# height: 337, width: 600
# FPS: 25.0671097219151
# odict_keys([])
# height: 337, width: 600
# FPS: 22.788194897205198
# odict_keys([])
# height: 337, width: 600
# [[188  23 250 130]
#  [ 55 407 102 473]
#  [ 87 465 147 547]]
# [False  True  True]
# Valid_rects
#  [[ 55 407 102 473]
#  [ 87 465 147 547]]
# FPS: 11.021660697252143
# odict_keys(['obj_19', 'obj_20'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 14.329653810543865
# odict_keys([])
# height: 337, width: 600
# FPS: 22.788071086674236
# odict_keys([])
# height: 337, width: 600
# FPS: 24.4555849032401
# odict_keys([])
# height: 337, width: 600
# [[ 94 471 156 557]
#  [186  28 246 124]
#  [ 60 417 110 482]]
# [ True False  True]
# Valid_rects
#  [[ 94 471 156 557]
#  [ 60 417 110 482]]
# FPS: 11.795967612656826
# odict_keys(['obj_21', 'obj_22'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 17.59916751984693
# odict_keys([])
# height: 337, width: 600
# FPS: 25.06651048545662
# odict_keys([])
# height: 337, width: 600
# FPS: 25.0678588077792
# odict_keys([])
# height: 337, width: 600
# [[182  30 242 125]
#  [100 477 164 563]
#  [ 65 426 114 493]]
# [False  True  True]
# Valid_rects
#  [[100 477 164 563]
#  [ 65 426 114 493]]
# FPS: 11.659200204591068
# odict_keys(['obj_23', 'obj_24'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 17.90494079076558
# odict_keys([])
# height: 337, width: 600
# FPS: 25.73018998717878
# odict_keys([])
# height: 337, width: 600
# FPS: 25.083599959333306
# odict_keys([])
# height: 337, width: 600
# [[181  34 236 123]
#  [ 70 434 121 503]
#  [108 479 173 568]]
# [False  True  True]
# Valid_rects
#  [[ 70 434 121 503]
#  [108 479 173 568]]
# FPS: 11.936389404305212
# odict_keys(['obj_25', 'obj_26'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 17.905246531483456
# odict_keys([])
# height: 337, width: 600
# FPS: 25.0671097219151
# odict_keys([])
# height: 337, width: 600
# FPS: 25.06695991011451
# odict_keys([])
# height: 337, width: 600
# [[179  38 230 124]
#  [ 76 439 126 513]
#  [116 478 183 575]]
# [False  True  True]
# Valid_rects
#  [[ 76 439 126 513]
#  [116 478 183 575]]
# FPS: 11.800613902557739
# odict_keys(['obj_27', 'obj_28'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 16.437743716761442
# odict_keys([])
# height: 337, width: 600
# FPS: 25.066810100104586
# odict_keys([])
# height: 337, width: 600
# FPS: 22.787947277488616
# odict_keys([])
# height: 337, width: 600
# [[123 480 194 581]
#  [176  40 224 127]
#  [ 81 444 131 519]]
# [ True False  True]
# Valid_rects
#  [[123 480 194 581]
#  [ 81 444 131 519]]
# FPS: 11.936831020988972
# odict_keys(['obj_29', 'obj_30'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 17.90448219926577
# odict_keys([])
# height: 337, width: 600
# FPS: 24.470994579898367
# odict_keys([])
# height: 337, width: 600
# FPS: 23.871963574274332
# odict_keys([])
# height: 337, width: 600
# [[ 85 449 141 528]
#  [131 479 207 583]
#  [172  45 220 132]]
# [ True  True False]
# Valid_rects
#  [[ 85 449 141 528]
#  [131 479 207 583]]
# FPS: 11.796067137650182
# odict_keys(['obj_31', 'obj_32'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 17.29488654403609
# odict_keys([])
# height: 337, width: 600
# FPS: 25.71078990277931
# odict_keys([])
# height: 337, width: 600
# FPS: 25.085250176433295
# odict_keys([])
# height: 337, width: 600
# [[139 475 221 582]
#  [ 93 452 147 538]
#  [169  53 217 137]]
# [ True  True False]
# Valid_rects
#  [[139 475 221 582]
#  [ 93 452 147 538]]
# FPS: 11.936797049314695
# odict_keys(['obj_33', 'obj_34'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 18.230318203352848
# odict_keys(['obj_33'])
# height: 337, width: 600
# tracked_box
# FPS: 20.889944765689982
# odict_keys(['obj_33'])
# height: 337, width: 600
# tracked_box
# FPS: 20.05299267071777
# odict_keys([])
# height: 337, width: 600
# [[ 98 454 157 546]
#  [148 471 235 576]
#  [164  61 214 144]]
# [ True  True False]
# Valid_rects
#  [[ 98 454 157 546]
#  [148 471 235 576]]
# FPS: 11.398184683950214
# odict_keys(['obj_35', 'obj_36'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 16.711173442555022
# odict_keys(['obj_36'])
# height: 337, width: 600
# tracked_box
# FPS: 20.88838423076157
# odict_keys(['obj_36'])
# height: 337, width: 600
# tracked_box
# FPS: 20.902437444246765
# odict_keys([])
# height: 337, width: 600
# [[156 465 250 570]
#  [104 455 166 552]
#  [161  71 211 151]]
# [ True  True False]
# Valid_rects
#  [[156 465 250 570]
#  [104 455 166 552]]
# FPS: 11.663285282078661
# odict_keys(['obj_37', 'obj_38'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 18.23039744080114
# odict_keys(['obj_37'])
# height: 337, width: 600
# tracked_box
# FPS: 20.065655961612983
# odict_keys(['obj_37'])
# height: 337, width: 600
# tracked_box
# FPS: 19.282560523726772
# odict_keys([])
# height: 337, width: 600
# [[164 451 261 556]
#  [114 453 176 556]
#  [ 24 369  91 453]]
# [ True  True  True]
# Valid_rects
#  [[164 451 261 556]
#  [114 453 176 556]
#  [ 24 369  91 453]]
# FPS: 10.131291440717883
# odict_keys(['obj_39', 'obj_40', 'obj_41'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 15.666405205321858
# odict_keys(['obj_39'])
# height: 337, width: 600
# tracked_box
# FPS: 20.889632640051
# odict_keys(['obj_39'])
# height: 337, width: 600
# tracked_box
# FPS: 20.8897366808943
# odict_keys([])
# height: 337, width: 600
# [[173 426 275 541]
#  [ 27 372  97 466]
#  [123 453 186 563]]
# [ True  True  True]
# Valid_rects
#  [[173 426 275 541]
#  [ 27 372  97 466]
#  [123 453 186 563]]
# FPS: 10.835195040041333
# odict_keys(['obj_42', 'obj_43', 'obj_44'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 15.666873351810487
# odict_keys(['obj_42'])
# height: 337, width: 600
# tracked_box
# FPS: 20.476300668336286
# odict_keys(['obj_42'])
# height: 337, width: 600
# tracked_box
# FPS: 20.029626799742125
# odict_keys([])
# height: 337, width: 600
# [[182 392 290 525]
#  [130 448 197 561]
#  [ 26 376 104 480]]
# [ True  True  True]
# Valid_rects
#  [[182 392 290 525]
#  [130 448 197 561]
#  [ 26 376 104 480]]
# FPS: 11.02223997519256
# odict_keys(['obj_45', 'obj_46', 'obj_47'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 15.91572939908626
# odict_keys(['obj_45'])
# height: 337, width: 600
# tracked_box
# FPS: 20.47410169921751
# odict_keys(['obj_45'])
# height: 337, width: 600
# tracked_box
# FPS: 20.05299267071777
# odict_keys([])
# height: 337, width: 600
# [[192 361 306 510]
#  [139 442 209 559]
#  [ 30 381 108 495]]
# [ True  True  True]
# Valid_rects
#  [[192 361 306 510]
#  [139 442 209 559]
#  [ 30 381 108 495]]
# FPS: 11.140663929070403
# odict_keys(['obj_48', 'obj_49', 'obj_50'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 14.965279784778195
# odict_keys(['obj_48'])
# height: 337, width: 600
# tracked_box
# FPS: 21.34896978581318
# odict_keys(['obj_48'])
# height: 337, width: 600
# tracked_box
# FPS: 15.666873351810487
# odict_keys([])
# height: 337, width: 600
# [[201 324 319 490]
#  [148 430 222 556]
#  [ 32 387 115 507]]
# [ True  True  True]
# Valid_rects
#  [[201 324 319 490]
#  [148 430 222 556]
#  [ 32 387 115 507]]
# FPS: 10.336628295269993
# odict_keys(['obj_51', 'obj_52', 'obj_53'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 16.180542321357617
# odict_keys(['obj_51', 'obj_52'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 17.913428972892635
# odict_keys(['obj_51', 'obj_52'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 17.904023631256777
# odict_keys([])
# height: 337, width: 600
# [[205 287 332 460]
#  [155 420 234 543]
#  [ 37 399 119 516]]
# [ True  True  True]
# Valid_rects
#  [[205 287 332 460]
#  [155 420 234 543]
#  [ 37 399 119 516]]
# FPS: 10.898683885720224
# odict_keys(['obj_54', 'obj_55', 'obj_56'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 14.53151558196338
# odict_keys(['obj_54', 'obj_55'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 16.17211995959191
# odict_keys(['obj_54', 'obj_55'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 15.915065093741818
# odict_keys(['obj_54'])
# height: 337, width: 600
# [[209 260 331 429]
#  [161 414 252 530]
#  [ 45 414 124 528]]
# [ True  True  True]
# Valid_rects
#  [[209 260 331 429]
#  [161 414 252 530]
#  [ 45 414 124 528]]
# FPS: 11.14400873601454
# odict_keys(['obj_54', 'obj_57', 'obj_58'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 14.752105909207616
# odict_keys(['obj_54', 'obj_57'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 16.17255645910691
# odict_keys(['obj_54', 'obj_57'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 16.17249410059071
# odict_keys(['obj_54'])
# height: 337, width: 600
# [[212 216 335 399]
#  [172 397 268 516]
#  [ 52 420 131 535]]
# [ True  True  True]
# Valid_rects
#  [[212 216 335 399]
#  [172 397 268 516]
#  [ 52 420 131 535]]
# FPS: 10.231382258595666
# odict_keys(['obj_54', 'obj_59', 'obj_60'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# {'ep_green': 2}
# FPS: 8.499113473380898
# odict_keys(['obj_54', 'obj_59'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 14.965546770188109
# odict_keys(['obj_54', 'obj_59'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 16.1801678078889
# odict_keys(['obj_54'])
# height: 337, width: 600
# [[175 371 283 494]
#  [217 182 335 362]
#  [ 58 434 143 541]]
# [ True  True  True]
# Valid_rects
#  [[175 371 283 494]
#  [217 182 335 362]
#  [ 58 434 143 541]]
# FPS: 10.66658528707921
# odict_keys(['obj_54', 'obj_61', 'obj_62'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 14.531465236491636
# odict_keys(['obj_54', 'obj_61'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 15.666522239321091
# odict_keys(['obj_54', 'obj_61'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 15.915789793231157
# odict_keys(['obj_54'])
# height: 337, width: 600
# [[182 341 292 469]
#  [216 152 334 321]
#  [ 63 439 151 549]]
# [ True  True  True]
# Valid_rects
#  [[182 341 292 469]
#  [216 152 334 321]
#  [ 63 439 151 549]]
# FPS: 11.016768228619458
# odict_keys(['obj_54', 'obj_63', 'obj_64'])
# height: 337, width: 600
# tracked_box
# tracked_box
# tracked_box
# FPS: 14.531364546594697
# odict_keys(['obj_54', 'obj_63'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 15.923100869367147
# odict_keys(['obj_54', 'obj_63'])
# height: 337, width: 600
# tracked_box
# FPS: 20.46231528415383
# odict_keys([])
# height: 337, width: 600
# [[187 302 306 444]
#  [217 126 333 277]
#  [ 67 442 158 558]]
# [ True  True  True]
# Valid_rects
#  [[187 302 306 444]
#  [217 126 333 277]
#  [ 67 442 158 558]]
# FPS: 10.234902538774634
# odict_keys(['obj_65', 'obj_66', 'obj_67'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 18.23039744080114
# odict_keys(['obj_65'])
# height: 337, width: 600
# tracked_box
# FPS: 20.88900841675382
# odict_keys(['obj_65'])
# height: 337, width: 600
# tracked_box
# FPS: 20.05366380752938
# odict_keys([])
# height: 337, width: 600
# [[191 268 314 423]
#  [222  95 327 231]
#  [ 70 447 168 563]]
# [ True False  True]
# Valid_rects
#  [[191 268 314 423]
#  [ 70 447 168 563]]
# FPS: 11.796365722707062
# odict_keys(['obj_68', 'obj_69'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 13.549769341103802
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 18.579090514453785
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 18.578514446693628
# odict_keys(['obj_68'])
# height: 337, width: 600
# [[199 235 318 397]
#  [223  70 323 198]
#  [ 72 450 183 565]]
# [ True False  True]
# Valid_rects
#  [[199 235 318 397]
#  [ 72 450 183 565]]
# FPS: 11.658876114656763
# odict_keys(['obj_68', 'obj_70'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 16.437099536392957
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# {'ep_green': 3}
# FPS: 9.552221402348483
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 17.590826927028942
# odict_keys(['obj_68'])
# height: 337, width: 600
# [[203 201 321 368]
#  [219  44 314 178]
#  [ 78 453 198 566]]
# [ True False  True]
# Valid_rects
#  [[203 201 321 368]
#  [ 78 453 198 566]]
# FPS: 11.01841786567121
# odict_keys(['obj_68', 'obj_71'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 15.425793116637612
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 18.230952122226327
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 18.57736241833684
# odict_keys(['obj_68'])
# height: 337, width: 600
# [[203 170 321 339]
#  [212  32 303 158]
#  [ 85 449 208 568]]
# [ True False  True]
# Valid_rects
#  [[203 170 321 339]
#  [ 85 449 208 568]]
# FPS: 11.140752703309312
# odict_keys(['obj_68', 'obj_72'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 11.394159354540763
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 13.549813114002074
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 12.22800634387536
# odict_keys(['obj_68'])
# height: 337, width: 600
# [[204 146 319 310]
#  [ 92 439 217 564]
#  [209  19 292 143]]
# [ True  True False]
# Valid_rects
#  [[204 146 319 310]
#  [ 92 439 217 564]]
# FPS: 8.086106746609344
# odict_keys(['obj_68', 'obj_73'])
# height: 337, width: 600
# tracked_box
# tracked_box
# FPS: 14.122473442313844
# odict_keys(['obj_68'])
# height: 337, width: 600
# tracked_box
# FPS: 17.59097447941787
# odict_keys(['obj_68'])
# height: 337, width: 600
# FPS: 24.455014547171903
# odict_keys([])
# height: 337, width: 600
# [[ 97 428 230 561]
#  [207 129 312 280]
#  [202  12 283 132]]
# [ True  True False]
# Valid_rects
#  [[ 97 428 230 561]
#  [207 129 312 280]]
# FPS: 11.524934534653356
# odict_keys(['obj_74', 'obj_75'])
# height: 337, width: 600
# tracked_box
# FPS: 20.88880035061158
# odict_keys([])
# height: 337, width: 600
# FPS: 25.0671097219151
# odict_keys([])
# height: 337, width: 600
# FPS: 24.474421590080233
# odict_keys([])
# height: 337, width: 600
# [[104 418 241 560]
#  [206 110 310 247]
#  [198   6 275 118]]
# [ True False False]
# Valid_rects
#  [[104 418 241 560]]
# FPS: 12.378712754403361
# odict_keys(['obj_76'])
# height: 337, width: 600
# tracked_box
# FPS: 20.053472049570654
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31814113291044
# odict_keys([])
# height: 337, width: 600
# FPS: 24.471994025392085
# odict_keys([])
# height: 337, width: 600
# [[113 397 253 560]
#  [194   2 269 112]
#  [205  91 302 218]]
# [ True False False]
# Valid_rects
#  [[113 397 253 560]]
# FPS: 12.378639687870757
# odict_keys(['obj_77'])
# height: 337, width: 600
# tracked_box
# FPS: 20.889216487041057
# odict_keys(['obj_77'])
# height: 337, width: 600
# tracked_box
# FPS: 20.889944765689982
# odict_keys(['obj_77'])
# height: 337, width: 600
# tracked_box
# FPS: 20.47560094510945
# odict_keys([])
# height: 337, width: 600
# [[190   0 260 104]
#  [116 378 273 558]
#  [207  73 299 191]]
# [False  True False]
# Valid_rects
#  [[116 378 273 558]]
# FPS: 12.854764560934646
# odict_keys(['obj_78'])
# height: 337, width: 600
# tracked_box
# FPS: 17.28733054986543
# odict_keys(['obj_78'])
# height: 337, width: 600
# tracked_box
# FPS: 20.88900841675382
# odict_keys(['obj_78'])
# height: 337, width: 600
# tracked_box
# FPS: 20.054526763728514
# odict_keys([])
# height: 337, width: 600
# [[124 356 285 550]
#  [205  57 291 168]
#  [188   3 252 100]]
# [ True False False]
# Valid_rects
#  [[124 356 285 550]]
# FPS: 12.86028257456829
# odict_keys(['obj_79'])
# height: 337, width: 600
# tracked_box
# FPS: 20.889632640051
# odict_keys(['obj_79'])
# height: 337, width: 600
# tracked_box
# FPS: 21.333550349429824
# odict_keys(['obj_79'])
# height: 337, width: 600
# tracked_box
# FPS: 20.47410169921751
# odict_keys([])
# height: 337, width: 600
# [[135 334 301 542]
#  [202  45 281 150]
#  [184  12 241 100]]
# [ True False False]
# Valid_rects
#  [[135 334 301 542]]
# FPS: 11.940909026206032
# odict_keys(['obj_80'])
# height: 337, width: 600
# tracked_box
# FPS: 14.74536384378219
# odict_keys(['obj_80'])
# height: 337, width: 600
# tracked_box
# FPS: 19.659817009149542
# odict_keys(['obj_80'])
# height: 337, width: 600
# tracked_box
# FPS: 20.05366380752938
# odict_keys([])
# height: 337, width: 600
# [[144 309 313 526]
#  [196  35 267 141]
#  [180  18 226 104]]
# [ True False False]
# Valid_rects
#  [[144 309 313 526]]
# FPS: 12.692435021803139
# odict_keys(['obj_81'])
# height: 337, width: 600
# tracked_box
# FPS: 15.802159547293785
# odict_keys(['obj_81'])
# height: 337, width: 600
# tracked_box
# FPS: 17.287615561848
# odict_keys(['obj_81'])
# height: 337, width: 600
# tracked_box
# FPS: 19.661291532288306
# odict_keys([])
# height: 337, width: 600
# [[157 283 323 509]
#  [193  29 258 136]
#  [177  23 214 106]]
# [ True False False]
# Valid_rects
#  [[157 283 323 509]]
# FPS: 11.79629936916591
# odict_keys(['obj_82'])
# height: 337, width: 600
# tracked_box
# FPS: 18.23983161776537
# odict_keys(['obj_82'])
# height: 337, width: 600
# tracked_box
# FPS: 19.28229458305175
# odict_keys(['obj_82'])
# height: 337, width: 600
# tracked_box
# FPS: 19.878783282936954
# odict_keys([])
# height: 337, width: 600
# [[159 256 327 488]
#  [191  30 253 135]
#  [174  33 207 108]]
# [ True False False]
# Valid_rects
#  [[159 256 327 488]]
# FPS: 11.558250019289911
# odict_keys(['obj_83'])
# height: 337, width: 600
# tracked_box
# FPS: 19.148663023479838
# odict_keys(['obj_83'])
# height: 337, width: 600
# tracked_box
# FPS: 20.142843421633977
# odict_keys(['obj_83'])
# height: 337, width: 600
# tracked_box
# FPS: 19.282560523726772
# odict_keys([])
# height: 337, width: 600
# [[168 230 328 455]
#  [189  29 250 133]]
# [ True False]
# Valid_rects
#  [[168 230 328 455]]
# FPS: 11.658487230517784
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 16.99433563203488
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 16.994060208257363
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.28733054986543
# odict_keys(['obj_84'])
# height: 337, width: 600
# [[173 195 327 422]
#  [185  31 243 128]]
# [ True False]
# Valid_rects
#  [[173 195 327 422]]
# FPS: 11.936083688819199
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.90494079076558
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# {'ep_green': 3, 'ep_orange': 1}
# FPS: 8.952317530244432
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 11.796166664322978
# odict_keys(['obj_84'])
# height: 337, width: 600
# [[172 154 327 384]
#  [184  29 237 127]]
# [ True False]
# Valid_rects
#  [[172 154 327 384]]
# FPS: 9.83016192576586
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.590826927028942
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.591343371220063
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.297525569119102
# odict_keys(['obj_84'])
# height: 337, width: 600
# [[177 124 321 347]
#  [181  37 231 130]]
# [ True False]
# Valid_rects
#  [[177 124 321 347]]
# FPS: 11.79623301637122
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 16.45044437297522
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.297382898524425
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.286974298102447
# odict_keys(['obj_84'])
# height: 337, width: 600
# [[182  98 318 323]]
# [ True]
# Valid_rects
#  [[182  98 318 323]]
# FPS: 12.383902683870206
# odict_keys(['obj_84'])
# height: 337, width: 600
# tracked_box
# FPS: 17.590384284713746
# odict_keys(['obj_84'])
# height: 337, width: 600
# FPS: 23.63014794532896
# odict_keys([])
# height: 337, width: 600
# FPS: 24.37896841542378
# odict_keys([])
# height: 337, width: 600
# [[180  73 313 300]]
# [ True]
# Valid_rects
#  [[180  73 313 300]]
# FPS: 11.77788198822297
# odict_keys(['obj_85'])
# height: 337, width: 600
# FPS: 23.56708039983593
# odict_keys([])
# height: 337, width: 600
# FPS: 21.797084578407173
# odict_keys([])
# height: 337, width: 600
# FPS: 24.39300482125306
# odict_keys([])
# height: 337, width: 600
# [[179  47 313 278]]
# [False]
# Valid_rects
#  []
# FPS: 11.266167416973774
# odict_keys([])
# height: 337, width: 600
# FPS: 23.88814279449371
# odict_keys([])
# height: 337, width: 600
# FPS: 21.797537690792584
# odict_keys([])
# height: 337, width: 600
# FPS: 23.334746446354558
# odict_keys([])
# height: 337, width: 600
# [[179  32 312 245]]
# [False]
# Valid_rects
#  []
# FPS: 12.854646369607124
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31814113291044
# odict_keys([])
# height: 337, width: 600
# FPS: 22.810254625349415
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31749296745572
# odict_keys([])
# height: 337, width: 600
# [[180  23 312 230]]
# [False]
# Valid_rects
#  []
# FPS: 12.860440301710922
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31749296745572
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31762259766396
# odict_keys([])
# height: 337, width: 600
# FPS: 17.29709756439547
# odict_keys([])
# height: 337, width: 600
# [[179  19 306 210]]
# [False]
# Valid_rects
#  []
# FPS: 10.127793151075245
# odict_keys([])
# height: 337, width: 600
# FPS: 21.204879701110723
# odict_keys([])
# height: 337, width: 600
# FPS: 21.294666565125784
# odict_keys([])
# height: 337, width: 600
# FPS: 21.04602292114084
# odict_keys([])
# height: 337, width: 600
# [[178  16 297 192]]
# [False]
# Valid_rects
#  []
# FPS: 11.922783259283264
# odict_keys([])
# height: 337, width: 600
# FPS: 21.511347259476565
# odict_keys([])
# height: 337, width: 600
# FPS: 21.11499640054168
# odict_keys([])
# height: 337, width: 600
# FPS: 21.122758954111436
# odict_keys([])
# height: 337, width: 600
# [[173  19 288 176]]
# [False]
# Valid_rects
#  []
# FPS: 11.833407627678124
# odict_keys([])
# height: 337, width: 600
# FPS: 23.87372998571323
# odict_keys([])
# height: 337, width: 600
# FPS: 24.4555849032401
# odict_keys([])
# height: 337, width: 600
# FPS: 24.454871962311675
# odict_keys([])
# height: 337, width: 600
# [[169  20 278 159]]
# [False]
# Valid_rects
#  []
# FPS: 12.8548039585268
# odict_keys([])
# height: 337, width: 600
# FPS: 24.454016488065392
# odict_keys([])
# height: 337, width: 600
# FPS: 21.797424410930144
# odict_keys([])
# height: 337, width: 600
# FPS: 24.456868301671157
# odict_keys([])
# height: 337, width: 600
# [[166  22 270 152]]
# [False]
# Valid_rects
#  []
# FPS: 13.02170437223107
# odict_keys([])
# height: 337, width: 600
# FPS: 24.4554423117289
# odict_keys([])
# height: 337, width: 600
# FPS: 24.4554423117289
# odict_keys([])
# height: 337, width: 600
# FPS: 25.083899982656643
# odict_keys([])
# height: 337, width: 600
# [[161  25 263 145]]
# [False]
# Valid_rects
#  []
# FPS: 13.549988208423386
# odict_keys([])
# height: 337, width: 600
# FPS: 23.318011496936744
# odict_keys([])
# height: 337, width: 600
# FPS: 23.31814113291044
# odict_keys([])
# height: 337, width: 600
# FPS: 23.872914686413232
# odict_keys([])
# height: 337, width: 600
# [[160  27 253 136]]
# [False]
# Valid_rects
#  []
# FPS: 13.555374571779458
# odict_keys([])
# height: 337, width: 600
# FPS: 24.471708461206344
# odict_keys([])
# height: 337, width: 600
# FPS: 20.888904383164583
# odict_keys([])
# height: 337, width: 600
# FPS: 24.3616932298685
# odict_keys([])
# height: 337, width: 600
# [[158  28 240 132]]
# [False]
# Valid_rects
#  []
# FPS: 13.54968179615571
# odict_keys([])
# height: 337, width: 600
# FPS: 25.067708987024783
# odict_keys([])
# height: 337, width: 600
# FPS: 24.454871962311675
# odict_keys([])
# height: 337, width: 600
# FPS: 24.4554423117289
# odict_keys([])
# height: 337, width: 600
# [[154  31 234 132]]
# [False]
# Valid_rects
#  []
# FPS: 13.549550480854652
# odict_keys([])
# height: 337, width: 600
# FPS: 24.456155285913365
# odict_keys([])
# STOPPING APPLICATION
# MEAN FPS THROUGHOUT VIDEO: 17.547770700636942
